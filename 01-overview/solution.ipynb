# %% [markdown]
# # Introduction to AI-Assisted Development
#
# In this homework, we'll build an application with AI.
#
# You can use any tool you want: ChatGPT, Claude, GitHub Copilot, Codex, Cursor, Antigravity, etc.
#
# With chat-based applications you will need to copy code back-and-forth, so we recommend that you use an AI assistant in your IDE with agent mode.
#
# We will build a TODO application in Django.
#
# The app should be able to do the following:
#
# - Create, edit and delete TODOs
# - Assign due dates
# - Mark TODOs as resolved
#
# You will only need Python to get started (we also recommend that you use `uv`).
#
# You don't need to know Python or Django for doing this homework.
#
#
# ## Question 1: Install Django
#
# We want to install Django. Ask AI to help you with that.
#
# What's the command you used for that?
#
# There could be multiple ways to do it. Put the one that AI suggested in the homework form.

# %%
# !pip install google-genai dotenv rich -q
# Out:
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
from google import genai
from google.genai import types
import os
from rich.console import Console
from rich.markdown import Markdown

load_dotenv()

def query_gemini(prompt: str):
    generation_config = types.GenerateContentConfig(
        temperature=0.3
    )

    response = client_genai.models.generate_content(
        model="gemini-2.5-flash-lite",
        contents=prompt,
        config=generation_config
    )
    return response.text

def console_print(prompt_base:str, query: str, log: str):
    prompt = prompt_base.format(query=query, context=log)

    response = query_gemini(prompt=prompt)
    
    log += "User:" + query + "\n"
    log += "Gemini:" + response + "\n"

    md = Markdown(response)
    console.print(md)
    return

api_key = os.getenv("GEMINI_API_KEY")
client_genai = genai.Client(api_key=api_key)
console = Console()

log = ""

prompt_base = """
You are a senior software engineering instructor.
Your job is to provide complete, explicit, step-by-step guidance with no assumptions.
You must explain everything clearly, and give full working code examples when necessary.

Rules:
- Do NOT assume anything that is not explicitly stated.
- Provide every step needed for the solution, even if it seems obvious.
- The Django app the user wants to build is always named 'myapp'.
- Always cross-check your answer with the historical conversation I provide.
- Answer using only the information available in the conversation + the user's question.
- Ensure all instructions, commands, configs, folders, and code are complete and correct.
- Always respond with pedagogical clarity, in your own words.
- If additional steps are required to make something work, include them all.

Conversation history:
{context}

User question:
{query}
"""

# %%
query = "How do I install Django using Python and pip?"

console_print(prompt_base=prompt_base, query=query, log=log)
# Out:
# Okay, let's get Django installed on your system. We'll use Python and its package installer, pip, to achieve this.
#
# Here are the explicit, step-by-step instructions:
#
#                                         Step 1: Ensure Python is Installed
#
# Before we can install Django, we need to make sure you have Python installed on your computer.
#
#  1 Open your terminal or command prompt.
#     • On Windows: Press the Windows key + R, type cmd, and press Enter.
#     • On macOS: Open the Spotlight search (Command + Space), type Terminal, and press Enter.
#     • On Linux: Open your distribution's terminal application (often found in your applications menu or by pressing
#       Ctrl + Alt + T).
#  2 Check your Python version. In the terminal, type the following command and press Enter:
#
#     python --version
#
#    or, if the above doesn't work, try:
#
#     python3 --version
#
#    You should see output similar to Python 3.x.x (where x represents numbers). If you see an error like "command
#    not found" or "python is not recognized," you'll need to install Python first. You can download it from the
#    official Python website: ]8;id=599907;https://www.python.org/downloads/\https://www.python.org/downloads/]8;;\. Make sure to select the option to "Add Python to
#    PATH" during installation if prompted.
#
#                                           Step 2: Ensure pip is Installed
#
# pip is the package installer for Python. It usually comes bundled with Python installations (version 3.4 and
# later).
#
#  1 In the same terminal window, type the following command and press Enter:
#
#     pip --version
#
#    or, if the above doesn't work, try:
#
#     pip3 --version
#
#    You should see output indicating the pip version and its location. If you get an error, you might need to
#    upgrade pip or install it separately.
#     • To upgrade pip (if it's already installed but outdated):
#
#        python -m pip install --upgrade pip
#
#       or
#
#        python3 -m pip install --upgrade pip
#
#     • If pip is not installed: The easiest way to ensure pip is available is to install or reinstall Python, making
#       sure to check the option to install pip during the installation process.
#
#                                               Step 3: Install Django
#
# Now that we've confirmed Python and pip are ready, we can install Django.
#
#  1 In your terminal, run the following command:
#
#     pip install django
#
#    or, if you are using pip3 specifically:
#
#     pip3 install django
#
#    This command tells pip to download the latest stable version of Django from the Python Package Index (PyPI) and
#    install it into your Python environment.
#  2 Verify the installation. After the installation completes without errors, you can check if Django is installed
#    correctly by running:
#
#     python -m django --version
#
#    or
#
#     python3 -m django --version
#
#    This should output the installed Django version, for example, 4.2.7.
#
# You have now successfully installed Django on your system!

# %%
# !pip install django -q
# Out:
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Question 2: Project and App
#
# Now we need to create a project and an app for that.
#
# Follow the instructions from AI to do it. At some point, you will need to include the app you created in the project.
#
# What's the file you need to edit for that?
#
# - `settings.py`
# - `manage.py`
# - `urls.py`
# - `wsgi.py`

# %%
query = "What are the steps and commands to create a Django project and a Django app using Python?"
console_print(prompt_base=prompt_base, query=query, log=log)
# Out:
# Let's get started with creating a Django project and an app. We'll go through this step-by-step, ensuring you have
# all the necessary commands and explanations.
#
#                                     Step 1: Ensure Python and Pip are Installed
#
# Before we begin with Django, we need to make sure you have Python and its package installer, pip, set up on your
# system.
#
#  • Check Python Installation: Open your terminal or command prompt and type:
#
#     python --version
#
#    or
#
#     python3 --version
#
#    If you see a version number (e.g., Python 3.9.7), Python is installed.
#  • Check Pip Installation: Similarly, check for pip:
#
#     pip --version
#
#    or
#
#     pip3 --version
#
#    If you see a version number, pip is installed.
#  • If Python or Pip are not installed: You'll need to download and install them from the official Python website:
#    ]8;id=696050;https://www.python.org/downloads/\https://www.python.org/downloads/]8;;\. Make sure to check the option to "Add Python to PATH" during installation if
#    you're on Windows.
#
#                                        Step 2: Create a Virtual Environment
#
# It's a best practice to use virtual environments for your Python projects. This isolates the project's dependencies
# from your system's global Python installation, preventing conflicts.
#
#  1 Navigate to your desired project directory: Open your terminal or command prompt and use the cd command to go to
#    the folder where you want to create your Django project. For example:
#
#     cd Documents/my_django_projects
#
#    (Replace Documents/my_django_projects with your actual desired path.)
#  2 Create the virtual environment: We'll name our virtual environment venv. Run the following command:
#
#     python -m venv venv
#
#    or if python points to Python 2 on your system:
#
#     python3 -m venv venv
#
#    This command creates a new directory named venv in your current location. This directory will contain a copy of
#    Python and pip specifically for this project.
#  3 Activate the virtual environment:
#     • On Windows:
#
#        venv\Scripts\activate
#
#     • On macOS and Linux:
#
#        source venv/bin/activate
#
#    Once activated, you'll see (venv) at the beginning of your terminal prompt, indicating that the virtual
#    environment is active.
#
#                                               Step 3: Install Django
#
# With your virtual environment activated, you can now install Django.
#
#  1 Install Django using pip: In your activated virtual environment, run:
#
#     pip install django
#
#    This command downloads and installs the latest stable version of Django and its dependencies into your venv
#    directory.
#  2 Verify Django installation: You can check if Django is installed correctly by running:
#
#     pip freeze
#
#    You should see Django listed among the installed packages.
#
#                                           Step 4: Create a Django Project
#
# Now, let's create the main Django project.
#
#  1 Create the project: Make sure your virtual environment is still active. Navigate to the directory where you want
#    your project files to reside (this can be the same directory where you created venv, or a parent directory).
#    Then, run the following command:
#
#     django-admin startproject myproject .
#
#     • django-admin: This is the command-line utility for Django.
#     • startproject: This command tells django-admin to create a new project.
#     • myproject: This is the name of your Django project. You can choose any valid name.
#     • . (dot): This tells Django to create the project files in the current directory, rather than creating an
#       extra subdirectory named myproject. This is a common and clean way to structure your project.
#    After running this command, you will see a new directory structure created:
#
#     myproject/
#         manage.py
#         myproject/
#             __init__.py
#             settings.py
#             urls.py
#             asgi.py
#             wsgi.py
#     venv/
#         ... (virtual environment files)
#
#  2 Understand the project structure:
#     • manage.py: A command-line utility that lets you interact with your Django project in various ways (e.g.,
#       running the development server, creating apps, performing database migrations).
#     • myproject/ (inner directory): This is the actual Python package for your project.
#        • __init__.py: An empty file that tells Python this directory should be considered a Python package.
#        • settings.py: Contains all the configurations for your Django project (database settings, installed apps,
#          static file settings, etc.).
#        • urls.py: Defines the URL patterns for your project.
#        • asgi.py and wsgi.py: Entry points for ASGI-compatible web servers and WSGI-compatible web servers,
#          respectively.
#
#                                             Step 5: Create a Django App
#
# A Django project is made up of one or more "apps." An app is a self-contained module that performs a specific
# function (e.g., a blog app, a user authentication app).
#
#  1 Navigate to your project's root directory: Make sure you are in the directory that contains manage.py. If you
#    followed the django-admin startproject myproject . command with the dot, you should already be there.
#  2 Create the app: Run the following command:
#
#     python manage.py startapp myapp
#
#     • python manage.py: This executes the manage.py script.
#     • startapp: This command tells manage.py to create a new app.
#     • myapp: This is the name of your Django app. You can choose any valid name.
#    This will create a new directory named myapp within your project:
#
#     myproject/
#         manage.py
#         myproject/
#             __init__.py
#             settings.py
#             urls.py
#             asgi.py
#             wsgi.py
#         myapp/
#             __init__.py
#             admin.py
#             apps.py
#             models.py
#             tests.py
#             views.py
#     venv/
#         ... (virtual environment files)
#
#  3 Understand the app structure:
#     • __init__.py: An empty file indicating that this directory is a Python package.
#     • admin.py: Used to register your models with Django's admin interface.
#     • apps.py: Contains configuration for the app itself.
#     • models.py: Where you define your database models (your data structure).
#     • tests.py: Where you write your unit tests for the app.
#     • views.py: Where you write the logic for handling requests and returning responses.
#
#                                    Step 6: Register Your App in Project Settings
#
# For Django to recognize your new app, you need to add it to the INSTALLED_APPS list in your project's settings.py
# file.
#
#  1 Open settings.py: Navigate to the myproject directory (the inner one) and open the settings.py file in your code
#    editor.
#  2 Add your app to INSTALLED_APPS: Find the INSTALLED_APPS list. It will look something like this:
#
#     INSTALLED_APPS = [
#         'django.contrib.admin',
#         'django.contrib.auth',
#         'django.contrib.contenttypes',
#         'django.contrib.sessions',
#         'django.contrib.messages',
#         'django.contrib.staticfiles',
#     ]
#
#    Add the name of your app, 'myapp', to this list. It's good practice to add your custom apps after the default
#    ones.
#
#     INSTALLED_APPS = [
#         'django.contrib.admin',
#         'django.contrib.auth',
#         'django.contrib.contenttypes',
#         'django.contrib.sessions',
#         'django.contrib.messages',
#         'django.contrib.staticfiles',
#         'myapp',  # Add your app here
#     ]
#
#
#                                         Step 7: Run the Development Server
#
# Let's start the built-in development server to see your project in action.
#
#  1 Navigate to the project root: Ensure you are in the directory containing manage.py.
#  2 Run the development server:
#
#     python manage.py runserver
#
#    You should see output similar to this:
#
#     Watching for file changes with StatReloader
#     Performing system checks...
#
#     System check identified no issues (0 silenced).
#     October 26, 2023 - 10:00:00
#     Django version 4.2.6, using settings 'myproject.settings'
#     Starting development server at http://127.0.0.1:8000/
#     Quit the server with CONTROL-C.
#
#  3 View your project in the browser: Open your web browser and go to http://127.0.0.1:8000/. You should see a "The
#    install worked successfully! Congratulations!" page. This confirms that your Django project is set up and
#    running.
#
#                                         Step 8: Stop the Development Server
#
# To stop the server, go back to your terminal where the server is running and press Ctrl + C.
#
# You have now successfully created a Django project and a Django app, and registered the app within your project.

# %% [markdown]
# ## Question 3: Django Models
#
# Let's now proceed to creating models - the mapping from python objects to a relational database.
#
# For the TODO app, which models do we need? Implement them.
#
# What's the next step you need to take?
#
# - Run the application
# - Add the models to the admin panel
# - Run migrations
# - Create a makefile

# %%
query = "For the TODO app, which django models do we need? What's the next step you need to take?"
console_print(prompt_base=prompt_base, query=query, log=log)
# Out:
# Let's break down the Django models needed for your TODO app and the subsequent steps.
#
#                                           Django Models for the TODO App
#
# For a basic TODO application, you'll primarily need one core model to represent a single to-do item.
#
# 1. The TodoItem Model
#
# This model will store the details of each task. Here's what it should include:
#
#  • task: This will be a text field to hold the actual description of the to-do item.
#  • completed: This will be a boolean field to indicate whether the task has been completed or not. It's good
#    practice to default this to False since new tasks are initially not completed.
#  • created_at: A timestamp to record when the to-do item was created. This is useful for sorting or tracking.
#  • updated_at: A timestamp to record when the to-do item was last modified.
#
# Step-by-step Guide to Creating the Model:
#
#  1 Navigate to your app's models.py file: Inside your Django project, you have an app named myapp. Within the myapp
#    directory, you'll find a file named models.py. This is where you define your data structures.
#  2 Open myapp/models.py for editing.
#  3 Add the TodoItem model definition: You need to import the necessary components from Django's ORM
#    (Object-Relational Mapper) and then define your model class.
#
#     # myapp/models.py
#
#     from django.db import models
#
#     class TodoItem(models.Model):
#         task = models.CharField(max_length=200)  # The description of the to-do item
#         completed = models.BooleanField(default=False) # Whether the task is completed
#         created_at = models.DateTimeField(auto_now_add=True) # Timestamp when created
#         updated_at = models.DateTimeField(auto_now=True) # Timestamp when last updated
#
#         def __str__(self):
#             return self.task # This helps in displaying the object in the admin or shell
#
#    Explanation of the code:
#     • from django.db import models: This line imports the models module, which provides the base classes and field
#       types for defining your database models.
#     • class TodoItem(models.Model):: This defines a new class named TodoItem that inherits from models.Model. This
#       inheritance tells Django that this class represents a database table.
#     • task = models.CharField(max_length=200): This defines a field named task. models.CharField is used for string
#       fields, and max_length=200 specifies the maximum number of characters allowed for this field.
#     • completed = models.BooleanField(default=False): This defines a boolean field named completed.
#       models.BooleanField stores True or False values. default=False means that when a new TodoItem is created, its
#       completed status will automatically be set to False unless specified otherwise.
#     • created_at = models.DateTimeField(auto_now_add=True): This defines a DateTimeField named created_at.
#       auto_now_add=True means that this field will be automatically populated with the current date and time when
#       the object is first created.
#     • updated_at = models.DateTimeField(auto_now=True): This defines a DateTimeField named updated_at.
#       auto_now=True means that this field will be automatically updated with the current date and time every time
#       the object is saved (modified).
#     • def __str__(self):: This is a special Python method that defines how an object of this class should be
#       represented as a string. In this case, it will return the task string, which is very helpful when viewing
#       your to-do items in the Django admin interface or in the Python shell.
#
#                                                     Next Steps
#
# After defining your models, you need to inform Django about these changes and apply them to your database.
#
# 1. Create Database Migrations
#
# Migrations are Django's way of propagating changes you make to your models (like adding a new model or changing a
# field) into your database schema.
#
# Step-by-step Guide to Creating Migrations:
#
#  1 Open your terminal or command prompt.
#  2 Navigate to your Django project's root directory. This is the directory that contains your manage.py file.
#  3 Run the makemigrations command:
#
#     python manage.py makemigrations myapp
#
#    Explanation of the command:
#     • python manage.py: This is the standard way to run Django management commands.
#     • makemigrations: This command inspects your models.py files for any changes and creates migration files that
#       describe how to update your database schema to match those changes.
#     • myapp: This argument tells Django to only look for changes within the myapp application. It's good practice
#       to specify the app name, especially as your project grows.
#    When you run this command, Django will detect the new TodoItem model and create a new file in a migrations
#    folder within your myapp directory. This file will contain instructions for creating the TodoItem table in your
#    database.
#
# 2. Apply Migrations to the Database
#
# Once you have created the migration files, you need to apply them to your database so that the actual table is
# created.
#
# Step-by-step Guide to Applying Migrations:
#
#  1 Ensure your terminal is still in your Django project's root directory.
#  2 Run the migrate command:
#
#     python manage.py migrate
#
#    Explanation of the command:
#     • python manage.py: Again, this invokes the Django management utility.
#     • migrate: This command looks for any unapplied migration files (like the one just created for myapp) and
#       executes the SQL commands necessary to update your database schema accordingly.
#    After running this command, Django will create the myapp_todoitem table in your database, with columns
#    corresponding to the fields you defined in your TodoItem model.
#
# These are the essential models and the immediate next steps to get your TODO app's data structure set up in Django.

# %% [markdown]
# ## Question 4. TODO Logic
#
# Let's now ask AI to implement the logic for the TODO app. Where do we put it?
#
# - `views.py`
# - `urls.py`
# - `admin.py`
# - `tests.py`

# %%
query = "Help me to implement the logic for the TODO app. Where do we put the logic for the TODO app in django?"
console_print(prompt_base=prompt_base, query=query, log=log)
# Out:
# In Django, the core logic of your application, including how you handle data, process requests, and interact with
# the database, is primarily implemented within the views and models of your Django app.
#
# Let's break down where you'll put the logic for your TODO app:
#
#                                      1. Models (Defining Your Data Structure)
#
# The models.py file within your Django app is where you define the structure of your data. For a TODO app, this
# means defining what a "TODO item" looks like.
#
# Step 1: Navigate to your app's models.py file.
#
# If you haven't already created your Django app, you'll need to do that first. Assuming you have an app named myapp,
# the path will be: myapp/models.py
#
# Step 2: Define the Todo model.
#
# Open myapp/models.py and add the following code. This defines a Todo object that will represent a single task in
# your TODO list.
#
#
#  # myapp/models.py
#
#  from django.db import models
#
#  class Todo(models.Model):
#      # 'task' will be a text field to store the description of the TODO item.
#      # 'max_length' is a required argument for CharField and TextField.
#      task = models.CharField(max_length=200)
#
#      # 'completed' will be a boolean field to indicate if the task is done.
#      # 'default=False' means that when a new Todo item is created,
#      # it will be marked as not completed by default.
#      completed = models.BooleanField(default=False)
#
#      # The __str__ method is a special Python method that defines
#      # how an object of this class should be represented as a string.
#      # This is very useful for debugging and for displaying the object
#      # in the Django admin interface.
#      def __str__(self):
#          return self.task
#
#
# Explanation:
#
#  • from django.db import models: This line imports the necessary Django modules for defining database models.
#  • class Todo(models.Model):: This declares a Python class named Todo that inherits from models.Model. This
#    inheritance tells Django that this class represents a database table.
#  • task = models.CharField(max_length=200): This defines a field named task. CharField is used for short to
#    medium-length string fields. max_length=200 specifies the maximum number of characters allowed.
#  • completed = models.BooleanField(default=False): This defines a field named completed. BooleanField is used for
#    true/false values. default=False means that new Todo objects will automatically have completed set to False
#    unless specified otherwise.
#  • def __str__(self):: This is a standard Python method. When you print a Todo object or see it in the Django
#    admin, this method determines what text is displayed. Here, it will display the task description.
#
#                                       2. Views (Handling Requests and Logic)
#
# The views.py file within your Django app is where you write the Python functions or classes that handle incoming
# web requests, process data (often using your models), and return responses. This is where the core "logic" of your
# TODO app will reside – for example, how to add a new TODO, mark one as complete, or display the list.
#
# Step 1: Navigate to your app's views.py file.
#
# Assuming you have an app named myapp, the path will be: myapp/views.py
#
# Step 2: Implement view functions to handle TODO operations.
#
# Here's an example of how you might implement views for listing TODOs, adding a new TODO, and marking a TODO as
# complete.
#
#
#  # myapp/views.py
#
#  from django.shortcuts import render, redirect
#  from .models import Todo
#  from .forms import TodoForm # We'll create this form next
#
#  def todo_list(request):
#      # This view will display all the TODO items.
#      # It fetches all Todo objects from the database.
#      todos = Todo.objects.all()
#      # It then renders an HTML template, passing the list of todos to it.
#      return render(request, 'myapp/todo_list.html', {'todos': todos})
#
#  def add_todo(request):
#      # This view will handle adding a new TODO item.
#      if request.method == 'POST':
#          # If the request method is POST, it means the user has submitted a form.
#          form = TodoForm(request.POST)
#          if form.is_valid():
#              # If the form data is valid, save the new Todo item to the database.
#              form.save()
#              # Redirect the user to the todo_list page after successful addition.
#              return redirect('todo_list')
#      else:
#          # If the request method is not POST (e.g., GET),
#          # create an empty form to display to the user.
#          form = TodoForm()
#      # Render the template for adding a todo, passing the form to it.
#      return render(request, 'myapp/add_todo.html', {'form': form})
#
#  def mark_complete(request, todo_id):
#      # This view will mark a specific TODO item as completed.
#      # It takes the 'todo_id' from the URL.
#      todo = Todo.objects.get(id=todo_id)
#      if todo:
#          # If the todo item exists, set its 'completed' field to True.
#          todo.completed = True
#          todo.save() # Save the changes to the database.
#      # Redirect back to the todo list.
#      return redirect('todo_list')
#
#  def delete_todo(request, todo_id):
#      # This view will delete a specific TODO item.
#      todo = Todo.objects.get(id=todo_id)
#      if todo:
#          todo.delete() # Delete the todo item from the database.
#      return redirect('todo_list')
#
#
# Explanation:
#
#  • from django.shortcuts import render, redirect: Imports functions to render HTML templates and redirect users to
#    other URLs.
#  • from .models import Todo: Imports the Todo model we defined earlier.
#  • from .forms import TodoForm: Imports a TodoForm which we will define to handle form input.
#  • todo_list(request):
#     • todos = Todo.objects.all(): This is a Django ORM (Object-Relational Mapper) query. Todo.objects is the
#       manager for the Todo model, and .all() retrieves all records from the Todo table.
#     • render(request, 'myapp/todo_list.html', {'todos': todos}): This function renders an HTML template. It takes
#       the request object, the path to the template ('myapp/todo_list.html'), and a dictionary of context variables
#       ({'todos': todos}) that will be available in the template.
#  • add_todo(request):
#     • Handles both GET (displaying the form) and POST (processing the submitted form) requests.
#     • TodoForm(request.POST): Creates a form instance bound to the data submitted in the POST request.
#     • form.is_valid(): Checks if the submitted data conforms to the form's validation rules.
#     • form.save(): If the form is valid, this saves the data to the database as a new Todo object.
#     • redirect('todo_list'): After saving, it redirects the user to the URL named todo_list.
#  • mark_complete(request, todo_id):
#     • Todo.objects.get(id=todo_id): Retrieves a single Todo object from the database where the id matches the
#       todo_id passed in the URL.
#     • todo.completed = True: Updates the completed attribute of the retrieved Todo object.
#     • todo.save(): Saves the changes to the database.
#  • delete_todo(request, todo_id):
#     • todo.delete(): Removes the Todo object from the database.
#
#                                           3. Forms (Handling User Input)
#
# While not strictly "logic" in the same way as views, forms are crucial for handling user input and validating it
# before it reaches your views. This is where you define the structure of forms that users will interact with.
#
# Step 1: Navigate to your app's forms.py file.
#
# If this file doesn't exist, create it within your myapp directory. myapp/forms.py
#
# Step 2: Define the TodoForm.
#
# Open myapp/forms.py and add the following code:
#
#
#  # myapp/forms.py
#
#  from django import forms
#  from .models import Todo
#
#  class TodoForm(forms.ModelForm):
#      class Meta:
#          # This tells Django to create a form based on the Todo model.
#          model = Todo
#          # 'fields' specifies which fields from the model should be included in the form.
#          # We want to include 'task' and 'completed'.
#          fields = ['task', 'completed']
#
#
# Explanation:
#
#  • from django import forms: Imports the Django forms module.
#  • from .models import Todo: Imports the Todo model.
#  • class TodoForm(forms.ModelForm):: Defines a form class that is linked to a Django model.
#  • class Meta:: This inner class is used to configure the ModelForm.
#     • model = Todo: Specifies that this form is associated with the Todo model.
#     • fields = ['task', 'completed']: Indicates that the form should include the task and completed fields from the
#       Todo model.
#
#                                           4. URLs (Mapping URLs to Views)
#
# You need to tell Django which URL should trigger which view function. This is done in your urls.py files.
#
# Step 1: Create urls.py in your app directory if it doesn't exist.
#
# myapp/urls.py
#
# Step 2: Define URL patterns for your app.
#
#
#  # myapp/urls.py
#
#  from django.urls import path
#  from . import views
#
#  urlpatterns = [
#      # This pattern maps the root URL of the app ('') to the todo_list view.
#      # 'name='todo_list'' gives this URL pattern a name, which we can use for redirects.
#      path('', views.todo_list, name='todo_list'),
#
#      # This pattern maps '/add/' to the add_todo view.
#      path('add/', views.add_todo, name='add_todo'),
#
#      # This pattern maps '/complete/<int:todo_id>/' to the mark_complete view.
#      # '<int:todo_id>' captures an integer from the URL and passes it as 'todo_id' to the view.
#      path('complete/<int:todo_id>/', views.mark_complete, name='mark_complete'),
#
#      # This pattern maps '/delete/<int:todo_id>/' to the delete_todo view.
#      path('delete/<int:todo_id>/', views.delete_todo, name='delete_todo'),
#  ]
#
#
# Step 3: Include your app's URLs in your project's main urls.py.
#
# Open your project's main urls.py file (e.g., your_project_name/urls.py) and add the following:
#
#
#  # your_project_name/urls.py
#
#  from django.contrib import admin
#  from django.urls import path, include
#
#  urlpatterns = [
#      path('admin/', admin.site.urls),
#      # This line includes all the URL patterns defined in myapp/urls.py
#      # under the namespace 'myapp'.
#      path('myapp/', include('myapp.urls')),
#  ]
#
#
# Explanation:
#
#  • from django.urls import path, include: Imports necessary functions for URL routing.
#  • from . import views: Imports the views from the current app.
#  • urlpatterns = [...]: A list that defines the URL patterns.
#  • path('', views.todo_list, name='todo_list'): Maps the base URL of the app (when accessed via myapp/) to the
#    todo_list view.
#  • path('add/', views.add_todo, name='add_todo'): Maps the /add/ URL to the add_todo view.
#  • path('complete/<int:todo_id>/', views.mark_complete, name='mark_complete'): Maps URLs like /complete/1/ to the
#    mark_complete view, passing 1 as todo_id.
#  • path('delete/<int:todo_id>/', views.delete_todo, name='delete_todo'): Maps URLs like /delete/1/ to the
#    delete_todo view, passing 1 as todo_id.
#  • In the project's urls.py, path('myapp/', include('myapp.urls')) tells Django to look for URL patterns defined in
#    myapp.urls when the URL starts with /myapp/.
#
#                                     5. Templates (Presenting Data to the User)
#
# While not strictly "logic," templates are where you display the data processed by your views. You'll create HTML
# files that use Django's template language to show your TODO list and forms.
#
# Step 1: Create a templates directory inside your myapp directory.
#
# myapp/templates/
#
# Step 2: Create a directory named after your app inside the templates directory.
#
# myapp/templates/myapp/
#
# Step 3: Create your HTML template files.
#
#  • myapp/templates/myapp/todo_list.html:
#
#     <!-- myapp/templates/myapp/todo_list.html -->
#     <!DOCTYPE html>
#     <html>
#     <head>
#         <title>TODO List</title>
#     </head>
#     <body>
#         <h1>My TODOs</h1>
#         <ul>
#             {% for todo in todos %}
#                 <li>
#                     {{ todo.task }} -
#                     {% if todo.completed %}
#                         Completed
#                     {% else %}
#                         <a href="{% url 'mark_complete' todo.id %}">Mark as Complete</a>
#                     {% endif %}
#                     - <a href="{% url 'delete_todo' todo.id %}">Delete</a>
#                 </li>
#             {% empty %}
#                 <li>No TODOs yet!</li>
#             {% endfor %}
#         </ul>
#         <p><a href="{% url 'add_todo' %}">Add New TODO</a></p>
#     </body>
#     </html>
#
#  • myapp/templates/myapp/add_todo.html:
#
#     <!-- myapp/templates/myapp/add_todo.html -->
#     <!DOCTYPE html>
#     <html>
#     <head>
#         <title>Add TODO</title>
#     </head>
#     <body>
#         <h1>Add New TODO</h1>
#         <form method="post">
#             {% csrf_token %} {# This is crucial for security #}
#             {{ form.as_p }} {# Renders the form fields as paragraphs #}
#             <button type="submit">Add TODO</button>
#         </form>
#         <p><a href="{% url 'todo_list' %}">Back to List</a></p>
#     </body>
#     </html>
#
#
# Explanation:
#
#  • {% for todo in todos %}: This is a Django template tag that iterates over the todos list passed from the view.
#  • {{ todo.task }}: This displays the task attribute of the current todo object.
#  • {% if todo.completed %}: Conditional logic to check if the task is completed.
#  • {% url 'mark_complete' todo.id %}: This is a Django template tag that generates a URL based on the name of a URL
#    pattern ('mark_complete') and passes the todo.id as an argument.
#  • {% csrf_token %}: This is a security measure required for all forms that submit data.
#  • {{ form.as_p }}: This renders the form fields generated by TodoForm as HTML paragraphs.
#
#                                             Summary of Logic Placement:
#
#  • Models (models.py): Defines the data structure (e.g., what a TODO item is).
#  • Views (views.py): Contains the core application logic. This includes:
#     • Fetching data from the database (using models).
#     • Processing user input (often with forms).
#     • Performing actions like adding, updating, or deleting data.
#     • Deciding what data to send to the template.
#     • Returning responses (rendering templates or redirecting).
#  • Forms (forms.py): Handles user input validation and creation of forms for user interaction.
#  • URLs (urls.py): Maps incoming web requests to the appropriate view functions.
#
# By organizing your code in these files, you create a structured and maintainable Django application.

# %% [markdown]
# ## Question 5. Templates
#
# Next step is creating the templates. You will need at least two: the base one and the home one. Let's call them `base.html` and `home.html`.
#
# Where do you need to register the directory with the templates?
#
# - `INSTALLED_APPS` in project's `settings.py`
# - `TEMPLATES['DIRS']` in project's `settings.py`
# - `TEMPLATES['APP_DIRS']` in project's `settings.py`
# - In the app's `urls.py`

# %%
query = "How do I create the templates in Django? I need at least two for my TODO app: the base one and the home one"
console_print(prompt_base=prompt_base, query=query, log=log)
# Out:
# Okay, let's get your Django templates set up for your TODO app. We'll create a base.html template and a home.html
# template.
#
# Here's a step-by-step guide:
#
# Step 1: Locate or Create the templates Directory
#
# Django looks for templates in specific locations. The most common and recommended place is within your app's
# directory.
#
#  1 Navigate to your Django project's root directory. This is the directory that contains your manage.py file.
#  2 Navigate into your app's directory. Based on our previous interactions, your app is named myapp. So, you'll go
#    into myapp/.
#  3 Check if a templates directory already exists inside myapp/.
#     • If it does not exist, create it.
#        • On Linux/macOS: Open your terminal, navigate to the myapp/ directory, and run:
#
#           mkdir templates
#
#        • On Windows: Open your Command Prompt or PowerShell, navigate to the myapp/ directory, and run:
#
#           mkdir templates
#
#     • If it does exist, you can proceed to the next step.
#
# Your directory structure should now look something like this:
#
#
#  your_project_root/
#  ├── manage.py
#  ├── your_project_name/
#  │   ├── __init__.py
#  │   ├── asgi.py
#  │   ├── settings.py
#  │   ├── urls.py
#  │   └── wsgi.py
#  └── myapp/
#      ├── __init__.py
#      ├── admin.py
#      ├── apps.py
#      ├── migrations/
#      ├── models.py
#      ├── templates/  <-- This is where we'll put our templates
#      ├── tests.py
#      ├── urls.py
#      └── views.py
#
#
# Step 2: Create the base.html Template
#
# This template will serve as the foundation for your other templates, containing common elements like the HTML
# structure, head section, and potentially a navigation bar.
#
#  1 Navigate into the templates directory you just created (or found) inside myapp/.
#  2 Create a new file named base.html.
#     • On Linux/macOS:
#
#        touch base.html
#
#     • On Windows:
#
#        type nul > base.html
#
#  3 Open base.html in your code editor.
#  4 Add the following HTML content to base.html:
#
#     <!DOCTYPE html>
#     <html lang="en">
#     <head>
#         <meta charset="UTF-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <title>{% block title %}My TODO App{% endblock %}</title>
#         <style>
#             body { font-family: sans-serif; margin: 20px; }
#             h1 { color: #333; }
#             nav { margin-bottom: 20px; background-color: #f0f0f0; padding: 10px; }
#             nav a { margin-right: 15px; text-decoration: none; color: #007bff; }
#             nav a:hover { text-decoration: underline; }
#         </style>
#     </head>
#     <body>
#         <nav>
#             <a href="{% url 'home' %}">Home</a>
#             <!-- You can add more navigation links here later -->
#         </nav>
#
#         <main>
#             {% block content %}
#                 <!-- Content from child templates will go here -->
#             {% endblock %}
#         </main>
#
#         <footer>
#             <p>&copy; 2023 My TODO App</p>
#         </footer>
#     </body>
#     </html>
#
#    Explanation of base.html:
#     • <!DOCTYPE html>, <html>, <head>, <body>: Standard HTML structure.
#     • <meta charset="UTF-8">, <meta name="viewport" ...>: Essential meta tags for character encoding and responsive
#       design.
#     • <title>{% block title %}My TODO App{% endblock %}</title>: This is a Django template tag.
#        • {% block title %}: Defines a block named title. Other templates can override this block to provide their
#          own specific title.
#        • My TODO App: This is the default title if no other template provides one.
#        • {% endblock %}: Marks the end of the title block.
#     • <style>: Basic CSS for demonstration purposes.
#     • <nav>: A navigation section.
#        • <a href="{% url 'home' %}">Home</a>: This uses another Django template tag.
#           • {% url 'home' %}: This tag dynamically generates the URL for a view that has been named 'home' in your
#             urls.py. This is a best practice as it decouples your templates from hardcoded URLs.
#     • <main>: The main content area.
#     • {% block content %}: This is the most important block. It's where the content from your specific page
#       templates (like home.html) will be inserted.
#     • <footer>: A simple footer.
#
# Step 3: Create the home.html Template
#
# This template will extend the base.html template and provide the specific content for your home page.
#
#  1 Ensure you are still inside the myapp/templates/ directory.
#  2 Create a new file named home.html.
#     • On Linux/macOS:
#
#        touch home.html
#
#     • On Windows:
#
#        type nul > home.html
#
#  3 Open home.html in your code editor.
#  4 Add the following HTML content to home.html:
#
#     {% extends 'base.html' %}
#
#     {% block title %}Home - My TODO App{% endblock %}
#
#     {% block content %}
#         <h1>Welcome to Your TODO App!</h1>
#         <p>This is your personalized dashboard. You can manage your tasks here.</p>
#         <p>No tasks yet? <a href="#">Add a new task</a>.</p>
#         <!-- Task list will go here later -->
#     {% endblock %}
#
#    Explanation of home.html:
#     • {% extends 'base.html' %}: This is a crucial Django template tag. It tells Django that this template inherits
#       from base.html. All the content in base.html will be included, and the blocks defined in base.html can be
#       overridden here.
#     • {% block title %}Home - My TODO App{% endblock %}: This overrides the title block from base.html. The title
#       of this specific page will now be "Home - My TODO App".
#     • {% block content %}: This overrides the content block from base.html. The HTML inside this block will be
#       inserted into the {% block content %} section of base.html.
#     • <h1>, <p>, <a>: Standard HTML elements for the content of your home page.
#
# Step 4: Configure Django to Find Your Templates
#
# You need to tell Django where to look for your templates. This is done in your project's settings.py file.
#
#  1 Open your project's settings.py file. This file is usually located in your_project_name/settings.py.
#  2 Locate the TEMPLATES setting. It will look something like this:
#
#     TEMPLATES = [
#         {
#             'BACKEND': 'django.template.backends.django.DjangoTemplates',
#             'DIRS': [],  # This is what we need to modify
#             'APP_DIRS': True,
#             'OPTIONS': {
#                 'context_processors': [
#                     'django.template.context_processors.debug',
#                     'django.template.context_processors.request',
#                     'django.contrib.auth.context_processors.auth',
#                     'django.contrib.messages.context_processors.messages',
#                 ],
#             },
#         },
#     ]
#
#  3 Modify the DIRS list within the TEMPLATES setting.
#     • We want Django to look for templates in the templates directory at the project level (i.e., alongside
#       manage.py). This is a common practice for project-wide templates or for a central templates folder.
#     • Important: If you are placing templates inside your app's directory (like we did with myapp/templates/), you
#       do not need to add myapp/templates/ to DIRS if APP_DIRS is set to True (which it is by default). Django will
#       automatically find templates in app_name/templates/ directories when APP_DIRS is True.
#    However, for clarity and to ensure it works, let's explicitly add the project-level templates directory.
#     • Create a templates directory at the root of your project. This is the directory that contains manage.py.
#        • On Linux/macOS:
#
#           cd .. # Go up one directory from myapp/ to the project root
#           mkdir templates
#
#        • On Windows:
#
#           cd .. # Go up one directory from myapp/ to the project root
#           mkdir templates
#
#     • Move your base.html and home.html from myapp/templates/ to this new project-level templates/ directory.
#        • On Linux/macOS:
#
#           mv myapp/templates/base.html templates/
#           mv myapp/templates/home.html templates/
#           rmdir myapp/templates # Remove the now empty directory
#
#        • On Windows:
#
#           move myapp\templates\base.html templates\
#           move myapp\templates\home.html templates\
#           rmdir myapp\templates # Remove the now empty directory
#
#     • Now, update settings.py to include this project-level templates directory:
#
#        import os # Make sure os is imported at the top of settings.py
#
#        TEMPLATES = [
#            {
#                'BACKEND': 'django.template.backends.django.DjangoTemplates',
#                'DIRS': [os.path.join(BASE_DIR, 'templates')], # Add this line
#                'APP_DIRS': True, # Keep this as True
#                'OPTIONS': {
#                    'context_processors': [
#                        'django.template.context_processors.debug',
#                        'django.template.context_processors.request',
#                        'django.contrib.auth.context_processors.auth',
#                        'django.contrib.messages.context_processors.messages',
#                    ],
#                },
#            },
#        ]
#
#       Explanation of the change:
#        • import os: Ensures the os module is available.
#        • os.path.join(BASE_DIR, 'templates'): This dynamically creates the path to your templates directory.
#          BASE_DIR is a variable defined in settings.py that points to your project's root directory (where
#          manage.py is). This makes your configuration portable.
#    Alternative (and often preferred) approach: Keep templates inside myapp/templates/ and ensure APP_DIRS is True.
#    If you choose this, you don't need to modify DIRS or create a project-level templates folder. The
#    myapp/templates/ structure is perfectly valid and often cleaner for app-specific templates.
#    For this guide, let's stick with the project-level templates directory as it's a common pattern and explicitly
#    shows how to configure DIRS.
#
# Step 5: Create a View to Render home.html
#
# You need a Django view function that tells Django to render your home.html template.
#
#  1 Open your app's views.py file. This is myapp/views.py.
#  2 Add the following code to myapp/views.py:
#
#     from django.shortcuts import render
#
#     def home_view(request):
#         """
#         Renders the home page template.
#         """
#         return render(request, 'home.html')
#
#    Explanation of views.py:
#     • from django.shortcuts import render: Imports the render shortcut function, which is used to load a template
#       and pass a context to it.
#     • def home_view(request):: Defines a Python function that will act as our view. It takes an HttpRequest object
#       as an argument.
#     • return render(request, 'home.html'): This is the core of the view.
#        • request: The incoming HTTP request object.
#        • 'home.html': The name of the template file to render. Django will look for this file in the directories
#          specified in settings.py (DIRS and APP_DIRS).
#
# Step 6: Map a URL to Your Home View
#
# You need to tell Django which URL should trigger your home_view.
#
#  1 Open your app's urls.py file. If you don't have one, create it inside myapp/.
#     • On Linux/macOS:
#
#        touch myapp/urls.py
#
#     • On Windows:
#
#        type nul > myapp/urls.py
#
#  2 Add the following code to myapp/urls.py:
#
#     from django.urls import path
#     from . import views # Import views from the current app
#
#     urlpatterns = [
#         path('', views.home_view, name='home'), # Maps the root URL to home_view
#     ]
#
#    Explanation of myapp/urls.py:
#     • from django.urls import path: Imports the path function for defining URL patterns.
#     • from . import views: Imports the views module from the current app (myapp). The dot (.) signifies the current
#       directory.
#     • urlpatterns = [...]: A list that contains all the URL patterns for this app.
#     • path('', views.home_view, name='home'): This defines a URL pattern.
#        • '': An empty string. This means this pattern will match the root URL of your application (e.g.,
#          http://127.0.0.1:8000/).
#        • views.home_view: Specifies that when this URL is matched, the home_view function from your views.py should
#          be executed.
#        • name='home': This assigns a name to this URL pattern. This name ('home') is what we used in base.html with
#          {% url 'home' %} to dynamically generate the link.
#  3 Include your app's URLs in your project's main urls.py file.
#     • Open your project's main urls.py file (e.g., your_project_name/urls.py).
#     • Add the following lines:
#
#     from django.contrib import admin
#     from django.urls import path, include # Import 'include'
#
#     urlpatterns = [
#         path('admin/', admin.site.urls),
#         path('', include('myapp.urls')), # Include your app's URLs here
#     ]
#
#    Explanation of the change:
#     • from django.urls import path, include: We need to import include to be able to include URL configurations
#       from other files.
#     • path('', include('myapp.urls')): This line tells Django that for any URL that starts with an empty string
#       (i.e., the root of your site), it should then look into myapp.urls to find matching patterns. This
#       effectively prefixes all URLs defined in myapp/urls.py with nothing.
#
# Step 7: Run the Development Server
#
# Now, let's see your templates in action.
#
#  1 Open your terminal or command prompt.
#  2 Navigate to your project's root directory (where manage.py is located).
#  3 Run the Django development server:
#
#     python manage.py runserver
#
#  4 Open your web browser and go to http://127.0.0.1:8000/.
#
# You should see your "Welcome to Your TODO App!" message, styled with the basic CSS from base.html, and the
# navigation link. If you click the "Home" link, it will also take you to the same page, demonstrating that the {%
# url 'home' %} tag is working correctly.
#
# You have now successfully created and rendered two Django templates: a base template for common structure and a
# specific home page template that extends it.

# %% [markdown]
# ## Question 6. Tests
#
# Now let's ask AI to cover our functionality with tests.
#
# - Ask it which scenarios we should cover
# - Make sure they make sense
# - Let it implement it and run them
#
# Probably it will require a few iterations to make sure that tests pass and evertyhing is working.
#
# What's the command you use for running tests in the terminal?
#
# - `pytest`
# - `python manage.py test`
# - `python -m django run_tests`
# - `django-admin test`

# %%
query = "Generate all the test scenarios my Django TODO app needs (models, views, URLs, templates). Explain why each scenario matters, then implement the tests using Django’s TestCase and Client. Organize them into test files and show how to run them."
console_print(prompt_base=prompt_base, query=query, log=log)
# Out:
# Let's break down the testing strategy for your Django TODO app. We'll cover models, views, URLs, and templates,
# explaining the purpose of each test and providing complete, runnable code.
#
#                                       Understanding the Importance of Testing
#
# Testing is a crucial part of software development. It helps us:
#
#  • Ensure Correctness: Verify that your code behaves as expected under various conditions.
#  • Prevent Regressions: Catch bugs introduced by new code changes.
#  • Improve Design: Writing tests often forces you to think about how your code will be used, leading to better
#    design decisions.
#  • Facilitate Refactoring: Confidently make changes to your code knowing that your tests will alert you if
#    something breaks.
#
#                                             Project Structure for Tests
#
# In Django, tests are typically placed within a tests.py file inside each app. For more complex projects, you might
# create a tests directory within your app, containing multiple test files. We'll use the standard tests.py for
# simplicity here.
#
#                                          Test Scenarios and Implementation
#
# We will create tests for:
#
#  1 Models: Testing the data integrity and behavior of your database models.
#  2 Views: Testing the logic that handles requests and returns responses.
#  3 URLs: Testing that URLs are correctly mapped to their corresponding views.
#  4 Templates: While direct template testing is less common and often covered by view tests, we'll discuss how to
#    indirectly verify template rendering.
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                   1. Model Tests
#
# Why Model Tests Matter: Model tests ensure that your data structures are correctly defined and that your model
# methods (if any) function as intended. This is the foundation of your application's data management.
#
# Assumptions: Based on a typical TODO app, we'll assume you have a Todo model with at least a title and a completed
# field.
#
# File: myapp/tests.py
#
#
#  # myapp/tests.py
#
#  from django.test import TestCase
#  from .models import Todo
#
#  class TodoModelTestCase(TestCase):
#      """
#      Tests for the Todo model.
#      """
#
#      def setUp(self):
#          """
#          Set up test data that will be used across multiple test methods.
#          This method is called before each test method.
#          """
#          self.todo_item_1 = Todo.objects.create(title="Buy groceries", completed=False)
#          self.todo_item_2 = Todo.objects.create(title="Walk the dog", completed=True)
#
#      def test_todo_creation(self):
#          """
#          Test that a Todo item can be created successfully.
#          """
#          # We already created items in setUp, so let's create one more to be explicit
#          new_todo = Todo.objects.create(title="Learn Django testing", completed=False)
#          self.assertEqual(new_todo.title, "Learn Django testing")
#          self.assertFalse(new_todo.completed)
#          self.assertEqual(Todo.objects.count(), 3) # 2 from setUp + 1 new
#
#      def test_todo_defaults(self):
#          """
#          Test that default values for fields are set correctly.
#          Assuming 'completed' defaults to False if not provided.
#          """
#          # If your model has default values, test them here.
#          # For example, if 'completed' defaults to False:
#          default_todo = Todo.objects.create(title="Default test")
#          self.assertFalse(default_todo.completed)
#
#      def test_todo_str_representation(self):
#          """
#          Test the __str__ method of the Todo model.
#          This ensures that the object is represented by its title when printed.
#          """
#          self.assertEqual(str(self.todo_item_1), "Buy groceries")
#          self.assertEqual(str(self.todo_item_2), "Walk the dog")
#
#      def test_todo_update(self):
#          """
#          Test that a Todo item can be updated.
#          """
#          # Retrieve an item created in setUp
#          todo_to_update = Todo.objects.get(title="Buy groceries")
#          todo_to_update.completed = True
#          todo_to_update.save()
#
#          # Retrieve it again to confirm the update
#          updated_todo = Todo.objects.get(title="Buy groceries")
#          self.assertTrue(updated_todo.completed)
#
#      def test_todo_deletion(self):
#          """
#          Test that a Todo item can be deleted.
#          """
#          # Get the count before deletion
#          initial_count = Todo.objects.count()
#
#          # Get an item to delete
#          todo_to_delete = Todo.objects.get(title="Walk the dog")
#          todo_to_delete.delete()
#
#          # Check if the count has decreased
#          self.assertEqual(Todo.objects.count(), initial_count - 1)
#
#          # Verify the item is no longer in the database
#          with self.assertRaises(Todo.DoesNotExist):
#              Todo.objects.get(title="Walk the dog")
#
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                    2. URL Tests
#
# Why URL Tests Matter: URL tests ensure that your defined URL patterns correctly map to the intended views. This
# prevents "Page Not Found" errors and ensures users can access the right functionality.
#
# Assumptions: We'll assume you have a urls.py file in your myapp directory and a project-level urls.py that includes
# your app's URLs. We'll also assume you have views for listing todos, creating todos, and marking todos as complete.
#
# File: myapp/tests.py (add to the existing file)
#
#
#  # myapp/tests.py (continued)
#
#  from django.urls import reverse, resolve
#  from .views import todo_list, todo_create, todo_complete # Assuming these view names
#
#  class TodoURLTestCase(TestCase):
#      """
#      Tests for the URL patterns in the myapp.
#      """
#
#      def test_todo_list_url(self):
#          """
#          Test that the URL for the todo list maps to the correct view.
#          """
#          # reverse('url_name') generates the URL from its name.
#          # resolve(url) returns the view function that handles that URL.
#          url = reverse('todo_list') # Assuming 'todo_list' is the name for your list view URL
#          self.assertEqual(resolve(url).view_name, 'todo_list') # Ensure the resolved view name matches
#
#      def test_todo_create_url(self):
#          """
#          Test that the URL for creating a todo maps to the correct view.
#          """
#          url = reverse('todo_create') # Assuming 'todo_create' is the name for your create view URL
#          self.assertEqual(resolve(url).view_name, 'todo_create')
#
#      def test_todo_complete_url(self):
#          """
#          Test that the URL for marking a todo as complete maps to the correct view.
#          This test assumes the URL pattern includes a primary key (pk) for the todo item.
#          """
#          # We need a valid pk to test this. Let's create a temporary todo item.
#          temp_todo = Todo.objects.create(title="Temporary todo for URL test")
#          url = reverse('todo_complete', args=[temp_todo.pk]) # Assuming 'todo_complete' takes pk as an argument
#          self.assertEqual(resolve(url).view_name, 'todo_complete')
#          temp_todo.delete() # Clean up the temporary item
#
#      # Add more URL tests if you have other specific URL patterns (e.g., todo_detail, todo_update, todo_delete)
#
#
# Important Note on URL Naming: For reverse() to work, you MUST name your URL patterns in your myapp/urls.py file.
# For example:
#
#
#  # myapp/urls.py
#  from django.urls import path
#  from . import views
#
#  urlpatterns = [
#      path('', views.todo_list, name='todo_list'),
#      path('create/', views.todo_create, name='todo_create'),
#      path('complete/<int:pk>/', views.todo_complete, name='todo_complete'),
#      # ... other paths
#  ]
#
#
# And in your project's urls.py:
#
#
#  # your_project/urls.py
#  from django.contrib import admin
#  from django.urls import path, include
#
#  urlpatterns = [
#      path('admin/', admin.site.urls),
#      path('myapp/', include('myapp.urls')), # Include your app's URLs
#  ]
#
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                    3. View Tests
#
# Why View Tests Matter: View tests are critical because they verify the application's logic. They check if your
# views correctly handle incoming requests (GET, POST), process data, interact with models, and return the
# appropriate responses (HTML, redirects, JSON).
#
# Assumptions: We'll assume you have views for:
#
#  • todo_list: Displays all TODO items.
#  • todo_create: Handles creating new TODO items (POST request).
#  • todo_complete: Handles marking a TODO item as complete (POST request).
#
# We'll use Django's Client to simulate requests.
#
# File: myapp/tests.py (add to the existing file)
#
#
#  # myapp/tests.py (continued)
#
#  from django.test import Client, TestCase
#  from django.urls import reverse
#  from .models import Todo
#
#  class TodoViewTestCase(TestCase):
#      """
#      Tests for the views in the myapp.
#      """
#
#      def setUp(self):
#          """
#          Set up test data and the test client.
#          """
#          self.client = Client()
#          self.todo_item_1 = Todo.objects.create(title="Buy milk", completed=False)
#          self.todo_item_2 = Todo.objects.create(title="Pay bills", completed=False)
#          self.completed_todo = Todo.objects.create(title="Clean room", completed=True)
#
#          # URLs for testing
#          self.todo_list_url = reverse('todo_list')
#          self.todo_create_url = reverse('todo_create')
#          self.todo_complete_url_template = reverse('todo_complete', args=['{pk}']) # Template for complete URL
#
#      def test_todo_list_view_GET(self):
#          """
#          Test that the todo list view displays all non-completed todos.
#          """
#          response = self.client.get(self.todo_list_url)
#
#          self.assertEqual(response.status_code, 200) # Check if the request was successful
#          self.assertTemplateUsed(response, 'myapp/todo_list.html') # Check if the correct template was used
#
#          # Check if the context contains the expected data
#          # Assuming the context variable for todos is named 'todos'
#          self.assertIn('todos', response.context)
#          todos_in_context = response.context['todos']
#
#          # Check that only non-completed todos are listed (adjust if your list view shows all)
#          self.assertEqual(len(todos_in_context), 2)
#          self.assertIn(self.todo_item_1, todos_in_context)
#          self.assertIn(self.todo_item_2, todos_in_context)
#          self.assertNotIn(self.completed_todo, todos_in_context)
#
#      def test_todo_create_view_POST(self):
#          """
#          Test that the todo create view successfully creates a new todo item via POST.
#          """
#          new_todo_title = "New task from test"
#          response = self.client.post(self.todo_create_url, {'title': new_todo_title})
#
#          # Check for redirection after successful creation (common pattern)
#          self.assertEqual(response.status_code, 302) # 302 Found (Redirect)
#          self.assertRedirects(response, self.todo_list_url) # Verify redirection to the list page
#
#          # Check if the todo was actually created in the database
#          self.assertEqual(Todo.objects.count(), 4) # 3 from setUp + 1 new
#          newly_created_todo = Todo.objects.get(title=new_todo_title)
#          self.assertIsNotNone(newly_created_todo)
#          self.assertFalse(newly_created_todo.completed)
#
#      def test_todo_create_view_POST_invalid_data(self):
#          """
#          Test that the todo create view handles POST requests with invalid data (e.g., missing title).
#          """
#          # Attempt to create a todo without a title
#          response = self.client.post(self.todo_create_url, {'completed': False})
#
#          # Expecting an error message or the same page to be rendered with errors
#          # If your form handles errors and re-renders the page, status code might be 200
#          # If it returns an error response, it might be different. Let's assume it re-renders.
#          self.assertEqual(response.status_code, 200) # Or whatever status code your form returns on error
#          self.assertTemplateUsed(response, 'myapp/todo_form.html') # Assuming a form template is used for creation
#
#          # Check that no new todo was created
#          self.assertEqual(Todo.objects.count(), 3) # Should remain the count from setUp
#
#      def test_todo_complete_view_POST(self):
#          """
#          Test that the todo complete view marks a todo item as completed via POST.
#          """
#          todo_to_complete = Todo.objects.get(title="Buy milk")
#          complete_url = self.todo_complete_url_template.format(pk=todo_to_complete.pk)
#
#          # Perform a POST request to mark it as complete
#          response = self.client.post(complete_url)
#
#          # Check for redirection after successful completion
#          self.assertEqual(response.status_code, 302)
#          self.assertRedirects(response, self.todo_list_url)
#
#          # Verify the todo item is now marked as completed in the database
#          updated_todo = Todo.objects.get(pk=todo_to_complete.pk)
#          self.assertTrue(updated_todo.completed)
#
#      def test_todo_complete_view_POST_nonexistent_todo(self):
#          """
#          Test that the todo complete view handles POST requests for a non-existent todo.
#          """
#          non_existent_pk = 9999 # A pk that definitely doesn't exist
#          complete_url = self.todo_complete_url_template.format(pk=non_existent_pk)
#
#          # Attempt to complete a non-existent todo
#          response = self.client.post(complete_url)
#
#          # Expecting a 404 Not Found response or a redirect to the list with an error message
#          # Let's assume a 404 for simplicity, or adjust based on your error handling.
#          self.assertEqual(response.status_code, 404) # Or 302 if you redirect with an error
#
#      # Add more view tests for other functionalities like:
#      # - todo_detail view (if you have one)
#      # - todo_update view (GET and POST)
#      # - todo_delete view (POST)
#      # - Testing with authenticated users if your app requires it.
#
#
# Important Notes for View Tests:
#
#  • setUp Method: This is crucial for creating common data that multiple tests will use. It runs before each test
#    method.
#  • Client: This object simulates a web browser, allowing you to make requests (get, post, put, delete) to your
#    application.
#  • response.status_code: Checks if the HTTP status code is as expected (e.g., 200 for OK, 302 for Redirect, 404 for
#    Not Found).
#  • assertTemplateUsed(response, 'template_name.html'): Verifies that a specific template was rendered.
#  • response.context: Accesses the context dictionary passed to the template. This is how you check if your view
#    passed the correct data to the template.
#  • assertRedirects(response, expected_url): Checks if the response is a redirect and if it redirects to the correct
#    URL.
#  • reverse('url_name', args=[...]): Used to dynamically get URLs, making tests more robust to URL changes.
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                            4. Template Tests (Indirect)
#
# Why Template Tests Matter: Directly testing templates can be brittle. It's generally better to test the logic that
# renders the template (i.e., your views) and ensure the correct data is passed to the template. If the view tests
# pass and verify that the correct context is provided, you can be reasonably confident that the template will render
# as expected.
#
# However, you can indirectly test template rendering by:
#
#  • Checking response.content: You can assert that specific HTML strings or text are present in the rendered output.
#    This is useful for verifying static elements or specific dynamic content.
#  • Using assertTemplateUsed: As shown in the view tests, this confirms the correct template was chosen.
#
# Example of Indirect Template Testing within View Tests:
#
# Let's enhance the test_todo_list_view_GET to check for specific content rendered in the HTML.
#
# File: myapp/tests.py (modify test_todo_list_view_GET)
#
#
#  # myapp/tests.py (continued)
#
#  # ... (previous tests) ...
#
#  class TodoViewTestCase(TestCase):
#      """
#      Tests for the views in the myapp.
#      """
#
#      def setUp(self):
#          """
#          Set up test data and the test client.
#          """
#          self.client = Client()
#          self.todo_item_1 = Todo.objects.create(title="Buy milk", completed=False)
#          self.todo_item_2 = Todo.objects.create(title="Pay bills", completed=False)
#          self.completed_todo = Todo.objects.create(title="Clean room", completed=True)
#
#          # URLs for testing
#          self.todo_list_url = reverse('todo_list')
#          self.todo_create_url = reverse('todo_create')
#          self.todo_complete_url_template = reverse('todo_complete', args=['{pk}']) # Template for complete URL
#
#      def test_todo_list_view_GET(self):
#          """
#          Test that the todo list view displays all non-completed todos and their content.
#          """
#          response = self.client.get(self.todo_list_url)
#
#          self.assertEqual(response.status_code, 200)
#          self.assertTemplateUsed(response, 'myapp/todo_list.html')
#
#          # Check context data (as before)
#          self.assertIn('todos', response.context)
#          todos_in_context = response.context['todos']
#          self.assertEqual(len(todos_in_context), 2)
#          self.assertIn(self.todo_item_1, todos_in_context)
#          self.assertIn(self.todo_item_2, todos_in_context)
#          self.assertNotIn(self.completed_todo, todos_in_context)
#
#          # --- Indirect Template Content Test ---
#          # Check if the titles of the non-completed todos appear in the HTML response content.
#          # This assumes your template renders the title within an HTML element.
#          # You might need to adjust the exact string based on your template's HTML structure.
#          self.assertContains(response, "Buy milk", status_code=200)
#          self.assertContains(response, "Pay bills", status_code=200)
#
#          # Ensure the completed todo's title is NOT in the list (if your list view filters them out)
#          # If your list view shows ALL todos, you would assertContains for this one too.
#          # Assuming your list view only shows incomplete tasks:
#          self.assertNotContains(response, "Clean room", status_code=200)
#
#      # ... (rest of the view tests) ...
#
#
# Explanation of assertContains and assertNotContains:
#
#  • self.assertContains(response, text, status_code=200): This method checks if the response object contains the
#    given text within its content. It also verifies that the status_code is as expected. This is a convenient way to
#    check for specific strings in the rendered HTML.
#  • self.assertNotContains(response, text, status_code=200): The opposite of assertContains, it checks if the text
#    is not present in the response content.
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                Organizing Test Files
#
# For a small app like myapp, a single myapp/tests.py file is perfectly fine. As your app grows, you might want to
# organize tests into subdirectories:
#
#
#  myapp/
#      __init__.py
#      models.py
#      views.py
#      urls.py
#      tests/
#          __init__.py
#          test_models.py
#          test_views.py
#          test_urls.py
#          # test_forms.py (if you have forms)
#          # test_utils.py (for helper functions)
#
#
# If you adopt this structure, you would create the respective test_*.py files and place the relevant test classes
# within them. Django's test runner will discover these files automatically.
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                 Running Your Tests
#
# To run your tests, open your terminal, navigate to your Django project's root directory (where manage.py is
# located), and execute the following command:
#
#
#  python manage.py test
#
#
# Explanation:
#
#  • python manage.py: This is the standard command-line utility for managing your Django project.
#  • test: This subcommand tells Django to discover and run your tests.
#
# Django's test runner will:
#
#  1 Discover all files named test.py (or files matching test_*.py in a tests directory) within your installed apps.
#  2 Execute all classes that inherit from django.test.TestCase.
#  3 Run all methods within those classes whose names start with test_.
#  4 Report the results, indicating which tests passed and which failed.
#
# Running Specific Tests:
#
# You can also run specific tests if needed:
#
#  • Run tests for a specific app:
#
#     python manage.py test myapp
#
#  • Run tests for a specific test class:
#
#     python manage.py test myapp.tests.TodoModelTestCase
#
#  • Run a specific test method:
#
#     python manage.py test myapp.tests.TodoModelTestCase.test_todo_creation
#
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                         Summary of Test Scenarios Covered:
#
#  • Models:
#     • Successful creation of Todo objects.
#     • Correct default values (e.g., completed=False).
#     • Accurate string representation (__str__).
#     • Successful updating of Todo objects.
#     • Successful deletion of Todo objects.
#  • URLs:
#     • Mapping of URL names (todo_list, todo_create, todo_complete) to their respective views.
#  • Views:
#     • todo_list view: Correctly fetches and displays non-completed todos, uses the right template.
#     • todo_create view: Handles POST requests to create new todos, redirects correctly, and validates input.
#     • todo_complete view: Handles POST requests to mark todos as complete, redirects correctly, and handles
#       non-existent items.
#  • Templates (Indirectly):
#     • Verifying that specific text content from the Todo objects appears in the rendered HTML response.
#     • Ensuring that items filtered out by the view (e.g., completed tasks) do not appear in the list.
#
# By implementing these tests, you build a robust foundation for your TODO application, ensuring its core
# functionalities are reliable.

# %% [markdown]
# ## Running the app
#
# Now the application is developed and tested. Run it:
#
# ```bash
# python manage.py runserver
# ```
#
# Since we asked AI to test everything, it should just work. If it doesn't, iterate with AI until it works.
#
#
# ## Homework URL
#
# Commit your code to GitHub. You can create a repository for this course. Within the repository, create a folder, e.g. "01-todo", where you put the code.
#
# Use the link to this folder in the homework submission form.
#
#
# ## Tip
#
# You can copy-paste the homework description into the AI system of your choice. But make sure you understand (and follow) all the steps in the response.
